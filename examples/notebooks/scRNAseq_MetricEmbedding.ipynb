# %% [markdown]
# **Authored by [Will Connell](https://twitter.com/wilstc)**
#
# **Published 04/23/2020**
#
# **[Keiser Laboratory](https://www.keiserlab.org/), UCSF**
#
# **Find the Pytorch Metric Learning library [documentation](https://kevinmusgrave.github.io/pytorch-metric-learning/) & [GitHub](https://github.com/KevinMusgrave/pytorch-metric-learning/)**

# %% [markdown]
# ## Import the packages

# %%
# %matplotlib inline
import logging

# Viz
import matplotlib.pyplot as plt
import numpy as np

# Data manipulation
import pandas as pd
import record_keeper
import scanpy as sc
import seaborn as sns
import torch
import torch.nn as nn
from sklearn.manifold import TSNE
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import train_test_split

import pytorch_metric_learning
import pytorch_metric_learning.utils.logging_presets as logging_presets

# Main
from pytorch_metric_learning import losses, miners, samplers, testers, trainers

sns.set(rc={"figure.figsize": (8.7, 6.27)})
from IPython.display import set_matplotlib_formats

set_matplotlib_formats("retina")

# Logs
logging.getLogger().setLevel(logging.INFO)
logging.info("VERSION %s" % pytorch_metric_learning.__version__)
# Out:
# /tmp/ipykernel_88955/2440828281.py:28: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats("retina")
# INFO:root:VERSION 1.4.0

# %% [markdown]
# ## Models and Datasets

# %%
class EmbeddingNet(nn.Module):
    # Useful code from fast.ai tabular model
    # https://github.com/fastai/fastai/blob/3b7c453cfa3845c6ffc496dd4043c07f3919270e/fastai/tabular/models.py#L6
    def __init__(self, in_sz, out_sz, emb_szs, ps, use_bn=True, actn=nn.ReLU()):
        super(EmbeddingNet, self).__init__()
        self.in_sz = in_sz
        self.out_sz = out_sz
        self.n_embs = len(emb_szs) - 1
        if ps == 0:
            ps = np.zeros(self.n_embs)
        # input layer
        layers = [nn.Linear(self.in_sz, emb_szs[0]), actn]
        # hidden layers
        for i in range(self.n_embs):
            layers += self.bn_drop_lin(
                n_in=emb_szs[i], n_out=emb_szs[i + 1], bn=use_bn, p=ps[i], actn=actn
            )
        # output layer
        layers.append(nn.Linear(emb_szs[-1], self.out_sz))
        self.fc = nn.Sequential(*layers)

    def bn_drop_lin(
        self,
        n_in: int,
        n_out: int,
        bn: bool = True,
        p: float = 0.0,
        actn: nn.Module = None,
    ):
        # https://github.com/fastai/fastai/blob/3b7c453cfa3845c6ffc496dd4043c07f3919270e/fastai/layers.py#L44
        "Sequence of batchnorm (if `bn`), dropout (with `p`) and linear (`n_in`,`n_out`) layers followed by `actn`."
        layers = [nn.BatchNorm1d(n_in)] if bn else []
        if p != 0:
            layers.append(nn.Dropout(p))
        layers.append(nn.Linear(n_in, n_out))
        if actn is not None:
            layers.append(actn)
        return layers

    def forward(self, x):
        output = self.fc(x)
        return output


# This will be used to create train and val sets
class BasicDataset(torch.utils.data.Dataset):
    def __init__(self, data, labels):
        self.data = torch.from_numpy(data).float()
        self.labels = labels

    def __getitem__(self, index):
        return self.data[index], self.labels[index]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# ## Create the dataset and train/val splits

# %%
# get data and format
adata = sc.datasets.paul15()
# can try preprocessing here...
# sc.pp.recipe_zheng17(adata)
# Out:
# WARNING: In Scanpy 0.*, this returned logarithmized data. Now it returns non-logarithmized data.
#   0%|          | 0.00/9.82M [00:00<?, ?B/s]
# ... storing 'paul15_clusters' as categorical
# /home/liz0f/anaconda3/envs/pytorch1.8/lib/python3.8/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /home/liz0f/anaconda3/envs/pytorch1.8/lib/python3.8/contextlib.py:120: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   next(self.gen)

# %% [markdown]
# This dataset is from a 2015 *Cell* paper titled: ["Transcriptional Heterogeneity and Lineage Commitment in Myeloid Progenitors"](https://www.cell.com/cell/fulltext/S0092-8674(15)01493-2?_returnURL=https%3A%2F%2Flinkinghub.elsevier.com%2Fretrieve%2Fpii%2FS0092867415014932%3Fshowall%3Dtrue).
#
# We will use cell type clusters that the authors were able to define through canonical marker genes to train and validate embeddings. Then, we will project remaining clusters into the metric space. From the publication:
#
#
#
# > "We found that, while some of the single-cell clusters (e.g. C1–C6, C14–C15, C16–C17)
# form groups that express marker genes corresponding to erythrocyte, monocyte, and neutrophil progenitors,
# other clusters (C7–C13) showed specific and distinct progenitor expression distributions that were not
# aligned with a simple hierarchical model of the population"

# %%
# create dictionary of label map
label_map = dict(enumerate(adata.obs["paul15_clusters"].cat.categories))
label_map
# Out:
# {0: '1Ery',
#  1: '2Ery',
#  2: '3Ery',
#  3: '4Ery',
#  4: '5Ery',
#  5: '6Ery',
#  6: '7MEP',
#  7: '8Mk',
#  8: '9GMP',
#  9: '10GMP',
#  10: '11DC',
#  11: '12Baso',
#  12: '13Baso',
#  13: '14Mo',
#  14: '15Mo',
#  15: '16Neu',
#  16: '17Neu',
#  17: '18Eos',
#  18: '19Lymph'}

# %%
# extract of some of the most representative clusters for training/testing
clusters = [0, 1, 2, 3, 4, 5, 13, 14, 15, 16]
indices = adata.obs["paul15_clusters"].cat.codes.isin(clusters)
data, labels = adata.X[indices], adata.obs[indices]["paul15_clusters"].cat.codes.values

# extract holdout clusters for projection
hld_data, hld_labels = (
    adata.X[~indices],
    adata.obs[~indices]["paul15_clusters"].cat.codes.values,
)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    data, labels, stratify=labels, test_size=0.2, random_state=77
)

# %% [markdown]
# ## Initialize datasets, models, and optimizers

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training, validation, holdout set
train_dataset = BasicDataset(X_train, y_train)
val_dataset = BasicDataset(X_val, y_val)
hld_dataset = BasicDataset(hld_data, hld_labels)

# Set embedder model. This takes in the output of the trunk and outputs 64 dimensional embeddings
model = EmbeddingNet(
    in_sz=len(adata.var),
    out_sz=25,
    emb_szs=[1000, 500, 250, 100],
    ps=0,
    use_bn=False,
    actn=nn.ReLU(),
)
model = nn.DataParallel(model).to(device)

# Set optimizers
model_optimizer = torch.optim.Adam(model.parameters(), lr=0.00001, weight_decay=0.0001)

# %% [markdown]
# ##Create the loss, miner, sampler, and package them into dictionaries

# %%
# Set the loss function
loss = losses.TripletMarginLoss(margin=0.1)

# Set the mining function
miner = miners.MultiSimilarityMiner(epsilon=0.1)

# Set the dataloader sampler
sampler = samplers.MPerClassSampler(
    y_train.flatten(), m=4, length_before_new_iter=len(train_dataset)
)

# Set other training parameters
batch_size = 64
num_epochs = 10

# Package the above stuff into dictionaries.
models = {"trunk": model}
optimizers = {"trunk_optimizer": model_optimizer}
loss_funcs = {"metric_loss": loss}
mining_funcs = {"tuple_miner": miner}

# %% [markdown]
# ## Create the training and testing hooks

# %%
# Remove logs if you want to train with new parameters
# !rm -rf example_logs/ example_saved_models/ example_tensorboard/

# %%
record_keeper, _, _ = logging_presets.get_record_keeper(
    "example_logs", "example_tensorboard"
)
hooks = logging_presets.get_hook_container(record_keeper)
dataset_dict = {"train": train_dataset, "val": val_dataset}
model_folder = "example_saved_models"

# Create the tester
tester = testers.GlobalEmbeddingSpaceTester(
    end_of_testing_hook=hooks.end_of_testing_hook,
    dataloader_num_workers=2,
    use_trunk_output=True,
)

end_of_epoch_hook = hooks.end_of_epoch_hook(
    tester, dataset_dict, model_folder, test_interval=1, patience=5
)

# %% [markdown]
# ## Create the trainer

# %%
trainer = trainers.MetricLossOnly(
    models,
    optimizers,
    batch_size,
    loss_funcs,
    mining_funcs,
    train_dataset,
    sampler=sampler,
    dataloader_num_workers=2,
    end_of_iteration_hook=hooks.end_of_iteration_hook,
    end_of_epoch_hook=end_of_epoch_hook,
)
# Out:
# WARNING:PML:models is missing "embedder"

# %% [markdown]
# ## Train the model

# %%
trainer.train(num_epochs=num_epochs)
# Out:
# INFO:PML:Initializing dataloader
# INFO:PML:Initializing dataloader iterator
# INFO:PML:Done creating dataloader iterator
# INFO:PML:TRAINING EPOCH 1
# total_loss=0.09856: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:03<00:00,  6.77it/s]
# INFO:PML:Evaluating epoch 1
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.34it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 120.29it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.22902618652528506
# INFO:PML:TRAINING EPOCH 2
# total_loss=0.09780: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 41.82it/s]
# INFO:PML:Evaluating epoch 2
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 46.40it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 109.60it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.3014550682810787
# INFO:PML:TRAINING EPOCH 3
# total_loss=0.11169: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 46.77it/s]
# INFO:PML:Evaluating epoch 3
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 49.15it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 132.62it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.3396334615275075
# INFO:PML:TRAINING EPOCH 4
# total_loss=0.07913: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 43.47it/s]
# INFO:PML:Evaluating epoch 4
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 45.48it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 116.93it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.36193474040556545
# INFO:PML:TRAINING EPOCH 5
# total_loss=0.07724: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 49.44it/s]
# INFO:PML:Evaluating epoch 5
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.39it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 116.88it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.38362139725568045
# INFO:PML:TRAINING EPOCH 6
# total_loss=0.08710: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 46.26it/s]
# INFO:PML:Evaluating epoch 6
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.04it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 118.82it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.3981680539742944
# INFO:PML:TRAINING EPOCH 7
# total_loss=0.06869: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 43.49it/s]
# INFO:PML:Evaluating epoch 7
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 48.74it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 113.43it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.4043654291101957
# INFO:PML:TRAINING EPOCH 8
# total_loss=0.07021: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 48.65it/s]
# INFO:PML:Evaluating epoch 8
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 48.61it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 128.46it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.41895933813106345
# INFO:PML:TRAINING EPOCH 9
# total_loss=0.06240: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 45.92it/s]
# INFO:PML:Evaluating epoch 9
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.78it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 122.36it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.42184740111660984
# INFO:PML:TRAINING EPOCH 10
# total_loss=0.06147: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 43.72it/s]
# INFO:PML:Evaluating epoch 10
# INFO:PML:Getting embeddings for the val split
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.66it/s]
# INFO:PML:Getting embeddings for the train split
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 119.11it/s]
# INFO:PML:Computing accuracy for the train split w.r.t ['train']
# INFO:PML:running k-nn with k=1472
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# INFO:PML:Computing accuracy for the val split w.r.t ['val']
# INFO:PML:running k-nn with k=368
# INFO:PML:embedding dimensionality is 25
# INFO:PML:running k-means clustering with k=10
# INFO:PML:embedding dimensionality is 25
# WARNING clustering 368 points to 10 centroids: please provide at least 390 training points
# INFO:PML:New best accuracy! 0.4302043081779488

# %% [markdown]
# ## Evaluate Loss and Accuracies

# %%
loss_history = hooks.get_loss_history()
plt.plot(loss_history["metric_loss"], "r", alpha=0.5, label="loss")
plt.legend()

# %%
for c, ds in zip(["r", "b"], ["train", "val"]):
    accuracies = hooks.get_accuracy_history(tester, ds, return_all_metrics=True)
    plt.plot(accuracies["epoch"], accuracies["AMI_level0"], "{}x-".format(c), label=ds)
plt.legend()
plt.title("Adjusted Mutual Info")
# Out:
# Text(0.5, 1.0, 'Adjusted Mutual Info')

# %% [markdown]
# ## Visualize Embeddings

# %%
# extract embeddings
train_emb, train_lab = tester.get_all_embeddings(
    train_dataset, model, return_as_numpy=True
)
val_emb, val_lab = tester.get_all_embeddings(val_dataset, model, return_as_numpy=True)
hld_emb, hld_lab = tester.get_all_embeddings(hld_dataset, model, return_as_numpy=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 108.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 87.64it/s]

# %%
# Visualize embeddings using tSNE
# combine validation and holdout embeddings
comb_emb = np.concatenate((train_emb, val_emb))
comb_lab = np.concatenate((train_dataset.labels, val_dataset.labels))
comb_src = np.concatenate(
    (np.repeat("TRAIN", len(train_emb)), np.repeat("VAL", len(val_emb)))
)

comb_tsne = TSNE().fit_transform(comb_emb)
# Out:
# /home/liz0f/anaconda3/envs/pytorch1.8/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/liz0f/anaconda3/envs/pytorch1.8/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(x=comb_tsne[:, 0], y=comb_tsne[:, 1], hue=comb_src)
plt.title("Training & Val Embeddings tSNE")
plt.show()
sns.scatterplot(
    x=comb_tsne[:, 0],
    y=comb_tsne[:, 1],
    hue=[label_map[i] for i in comb_lab],
    style=comb_src,
    palette="Paired",
)
plt.title("Training & Val Embeddings tSNE")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
plt.show()

# %% [markdown]
# ## Project Holdout Samples

# %%
# combine validation and holdout embeddings
comb_hld_emb = np.concatenate((comb_emb, hld_emb))
comb_hld_lab = np.concatenate((comb_lab, hld_labels))
comb_hld_src = np.concatenate((comb_src, np.repeat("HLD", len(hld_emb))))

comb_hld_tsne = TSNE().fit_transform(comb_hld_emb)
# Out:
# /home/liz0f/anaconda3/envs/pytorch1.8/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/liz0f/anaconda3/envs/pytorch1.8/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(x=comb_hld_tsne[:, 0], y=comb_hld_tsne[:, 1], hue=comb_hld_src)
plt.title("Combined Embeddings tSNE")
plt.show()
sns.scatterplot(
    x=comb_hld_tsne[:, 0],
    y=comb_hld_tsne[:, 1],
    hue=[label_map[i] for i in comb_hld_lab],
    hue_order=label_map.values(),
    style=comb_hld_src,
    palette="Paired",
)
plt.title("Combined Embeddings tSNE")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
plt.show()

# %% [markdown]
# ## Score Cells in Embedding Space

# %%
# avergage embedding (prototypical) location of training clusters
comb_df = pd.DataFrame(comb_emb, comb_lab)
proto = comb_df.groupby(comb_df.index).mean()

# %%
proto
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.346726  0.290677  0.223462  0.055373  0.064952  0.081722  0.191606
# 1   0.268424  0.238179  0.328236  0.145389 -0.021675  0.097800  0.252513
# 2   0.207281  0.215788  0.371068  0.167978 -0.016000  0.062022  0.231844
# 3   0.182002  0.172505  0.368758  0.211259 -0.081416  0.093456  0.241964
# 4   0.171026  0.121020  0.333859  0.284404 -0.094013  0.110754  0.296737
# 5   0.161232  0.123215  0.336032  0.325928 -0.103795  0.086022  0.284257
# 13  0.026292  0.051396  0.317366  0.413008 -0.054660  0.049625  0.244029
# 14 -0.028962  0.067898  0.232894  0.372651  0.039272  0.068525  0.256309
# 15 -0.064446  0.113457  0.128504  0.309427  0.126133  0.055993  0.247781
# 16  0.193841  0.073242  0.301677  0.386403 -0.223181  0.014691  0.185574
#
#           7         8         9   ...        15        16        17        18  \
# 0  -0.249893 -0.036040 -0.129600  ...  0.006092 -0.183058  0.292507  0.062504
# 1  -0.236766  0.027928 -0.027533  ... -0.015086 -0.197782  0.224261  0.068936
# 2  -0.192928 -0.002065 -0.025928  ...  0.107552 -0.089469  0.308071  0.139717
# 3  -0.181437  0.080036  0.045506  ...  0.035853 -0.158534  0.183396  0.082374
# 4  -0.190714  0.074748  0.102196  ... -0.011302 -0.165506  0.084944  0.046020
# 5  -0.132755  0.017606  0.114851  ...  0.071375 -0.103026  0.153951  0.112241
# 13 -0.147424 -0.062294 -0.032937  ...  0.138647  0.067882  0.216962  0.155117
# 14 -0.185292 -0.085500 -0.117540  ...  0.210199  0.059019  0.256840  0.134127
# 15 -0.216768 -0.115224 -0.163500  ...  0.223164  0.052316  0.265785  0.074255
# 16  0.033212 -0.027231  0.094780  ...  0.164581 -0.107069  0.126497  0.171186
#
#           19        20        21        22        23        24
# 0   0.031421 -0.089575 -0.193048 -0.214588 -0.152057  0.306012
# 1   0.111290 -0.018451 -0.175887 -0.214572 -0.236164  0.315888
# 2   0.176643 -0.039717 -0.213266 -0.220375 -0.175487  0.326612
# 3   0.213777  0.028587 -0.183528 -0.237567 -0.280688  0.296060
# 4   0.180530  0.039236 -0.163141 -0.235495 -0.234834  0.231560
# 5   0.144897  0.013574 -0.184737 -0.283796 -0.098148  0.241338
# 13  0.184837 -0.009942 -0.265691 -0.215950  0.067097  0.221209
# 14  0.170088 -0.097265 -0.253955 -0.230940  0.150331  0.147691
# 15  0.108121 -0.139166 -0.218800 -0.224220  0.222718  0.071665
# 16  0.064510 -0.016093 -0.207184 -0.300008  0.095878  0.229122
#
# [10 rows x 25 columns]

# %%
# distances of holdout embeddings to cluster centers
sim = pairwise_distances(hld_emb, proto.values)

# %%
sim_df = pd.DataFrame(
    sim, [label_map[i] for i in hld_labels], [label_map[i] for i in proto.index]
)

# %%
# hierarchical clustering of relative location
sns.clustermap(sim_df)
